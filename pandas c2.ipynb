# %%
import pandas as pd

# %%
df=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1=df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv('nba.csv',index=False)

# %%
len(l)
# Out:
# 1

# %%
 l= pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)
# Out:
# 3

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  Ireland v India at Dublin (Malahide), 2nd T20I...
# 2  Ireland v India at Dublin (Malahide), 1st T20I...
# 3  India v South Africa at Bengaluru, 5th T20I, J...

# %%
l[0]
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
# 4          Avesh Khan  2022-2022    8    -  -     -    -      -    -       -
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 93      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 94  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 95           SA Yadav  2021-2022   16   14  3   366   65  33.27  218  167.88
# 96           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
# 97       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# 1    0  0  0   0   0
# 2    -  -  -   -   -
# 3    0  0  0  14   1
# 4    -  -  -   -   -
# ..  .. .. ..  ..  ..
# 93   0  0  0   0   0
# 94   0  0  3   4   3
# 95   0  4  2  34  21
# 96   0  0  0   0   0
# 97   0  8  1  77  74
#
# [98 rows x 15 columns]

# %%
d ="""{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
type(d)
# Out:
# str

# %%
import json

# %%
result=json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
result
# Out:
# {'name': 'Sudhanshu kumar',
#  'email id ': 'sskumar@gmail.com',
#  'tech': ['ML', 'DL', 'CV'],
#  'plateform': ['techneuron', 'kidsneuron', 'ineuron']}

# %%
result['name']
# Out:
# 'Sudhanshu kumar'

# %%
pd.DataFrame(result['tech'])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
result['tech']
# Out:
# ['ML', 'DL', 'CV']

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
d1=d['data']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticTroubleCodeData': [],
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
del d1['diagnosticTroubleCodeData']

# %%
d1
# Out:
# {'checkEngineLightFlag': 'F',
#  'batteryVoltageStableTime': 0,
#  'batteryVoltageStable': '0',
#  'batteryVoltageOff': '12.42',
#  'batteryCrankParamTN': '-0.08',
#  'batteryCrankParamVN': '0.00',
#  'batteryCrankParamTP': '-0.08',
#  'batteryCrankParamVP': '0.00',
#  'batteryCrankParamTT': '-0.00008',
#  'batteryCrankParamV0': '0.00',
#  'batteryVoltageMaxOn': '13.05',
#  'batteryVoltageMinOn': '12.97',
#  'batteryVoltageMaxOff': '12.46',
#  'batteryVoltageMinOff': '12.36',
#  'batteryVoltageOnAverage': '13.02',
#  'engineLoadMax': '84',
#  'engineLoadAverage': '39.98',
#  'rpmMax': '3487',
#  'rpmAverage': '1431.29',
#  'gpsSpeedAverage': '21.99',
#  'vssMax': '53.44',
#  'vssAverage': '23.06',
#  'tcuTemperatureMin': '82.40',
#  'tcuTemperatureMax': '109.40',
#  'tcuTemperatureAverage': '104.87',
#  'coolantMin': '158.00',
#  'coolantMax': '188.60',
#  'coolantAverage': '180.20',
#  'packetStartLocal': 1508143346000,
#  'tripStartLocal': 1508143346000,
#  'milIndicator': 'F',
#  'monitorsNotReady': 0,
#  'imei': '60DF5417',
#  'gatewayTs': 1515613306592,
#  'diagnosticPidData': [[64768, 47, 100],
#   [64768, 1, 517376],
#   [64800, 1, 262144],
#   [64768, 5, 125]]}

# %%
d2=pd.DataFrame(d1)

# %%
d2
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %%
pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues').head().T
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/47587  1292172196
# 1     https://github.com/pandas-dev/pandas/pull/47586  1292162378
# 2     https://github.com/pandas-dev/pandas/pull/47585  1292157615
# 3   https://github.com/pandas-dev/pandas/issues/47584  1292102669
# 4     https://github.com/pandas-dev/pandas/pull/47583  1292075128
# 5   https://github.com/pandas-dev/pandas/issues/47582  1292041116
# 6     https://github.com/pandas-dev/pandas/pull/47581  1292039468
# 7   https://github.com/pandas-dev/pandas/issues/47580  1292002886
# 8     https://github.com/pandas-dev/pandas/pull/47579  1291947280
# 9   https://github.com/pandas-dev/pandas/issues/47578  1291892216
# 10  https://github.com/pandas-dev/pandas/issues/47577  1291881775
# 11  https://github.com/pandas-dev/pandas/issues/47576  1291879073
# 12    https://github.com/pandas-dev/pandas/pull/47575  1291783181
# 13  https://github.com/pandas-dev/pandas/issues/47571  1291627218
# 14    https://github.com/pandas-dev/pandas/pull/47570  1291503075
# 15  https://github.com/pandas-dev/pandas/issues/47569  1291413614
# 16  https://github.com/pandas-dev/pandas/issues/47567  1291157380
# 17    https://github.com/pandas-dev/pandas/pull/47564  1291005009
# 18  https://github.com/pandas-dev/pandas/issues/47563  1290946951
# 19    https://github.com/pandas-dev/pandas/pull/47562  1290860991
# 20    https://github.com/pandas-dev/pandas/pull/47561  1290847203
# 21    https://github.com/pandas-dev/pandas/pull/47559  1290802961
# 22    https://github.com/pandas-dev/pandas/pull/47558  1290800722
# 23    https://github.com/pandas-dev/pandas/pull/47557  1290756094
# 24  https://github.com/pandas-dev/pandas/issues/47554  1290039010
# 25    https://github.com/pandas-dev/pandas/pull/47552  1289422658
# 26    https://github.com/pandas-dev/pandas/pull/47550  1288978436
# 27  https://github.com/pandas-dev/pandas/issues/47549  1288852049
# 28    https://github.com/pandas-dev/pandas/pull/47547  1288404337
# 29  https://github.com/pandas-dev/pandas/issues/47545  1288365319
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD846v07_   47587
# 1   PR_kwDOAA0YD846vzB0   47586
# 2   PR_kwDOAA0YD846vyHh   47585
# 3    I_kwDOAA0YD85NA-wN   47584
# 4   PR_kwDOAA0YD846viaA   47583
# 5    I_kwDOAA0YD85NAvuc   47582
# 6   PR_kwDOAA0YD846vbuJ   47581
# 7    I_kwDOAA0YD85NAmZG   47580
# 8   PR_kwDOAA0YD846vKXA   47579
# 9    I_kwDOAA0YD85NALX4   47578
# 10   I_kwDOAA0YD85NAI0v   47577
# 11   I_kwDOAA0YD85NAIKh   47576
# 12  PR_kwDOAA0YD846unoO   47575
# 13   I_kwDOAA0YD85M_KrS   47571
# 14  PR_kwDOAA0YD846tqo9   47570
# 15   I_kwDOAA0YD85M-Whu   47569
# 16   I_kwDOAA0YD85M9X-E   47567
# 17  PR_kwDOAA0YD846r-yY   47564
# 18   I_kwDOAA0YD85M8kmH   47563
# 19  PR_kwDOAA0YD846rgBR   47562
# 20  PR_kwDOAA0YD846rdFL   47561
# 21  PR_kwDOAA0YD846rT1Y   47559
# 22  PR_kwDOAA0YD846rTY_   47558
# 23  PR_kwDOAA0YD846rJ9C   47557
# 24   I_kwDOAA0YD85M5G7i   47554
# 25  PR_kwDOAA0YD846msHX   47552
# 26  PR_kwDOAA0YD846lLJG   47550
# 27   I_kwDOAA0YD85M0lJR   47549
# 28  PR_kwDOAA0YD846jPIc   47547
# 29   I_kwDOAA0YD85MyuUH   47545
#
#                                                 title  ... closed_at  \
# 0                     TYP: return values in core/*.py  ...       NaT
# 1    BUG: concat losing columns dtypes for join=outer  ...       NaT
# 2   BUG: Series map ignoring na_action for dict or...  ...       NaT
# 3   DOC: Indicate `formatters` in `DataFrame.to_st...  ...       NaT
# 4                         REF: share DTA/TDA.__init__  ...       NaT
# 5   BUG: loc aligning rhs with list indexer but no...  ...       NaT
# 6   BUG: DataFrame.loc not aligning rhs df for sin...  ...       NaT
# 7   BUG: pandas.Series.describe() displays confusi...  ...       NaT
# 8                ENH: DTI/DTA.astype support non-nano  ...       NaT
# 9   BUG: Setting a DataFrame as rhs with loc on a ...  ...       NaT
# 10  BUG: Setting incompatible values into ea colum...  ...       NaT
# 11  BUG: Spurious "FutureWarning: Use pd.to_dateti...  ...       NaT
# 12  Adding testcase for quartile performed on a ti...  ...       NaT
# 13  ENH: dataframe.astype() exception message to i...  ...       NaT
# 14  Fixed `tm.set_locale` context manager, it coul...  ...       NaT
# 15  CI 1.4.x: Typing error Overload 2 for "searchs...  ...       NaT
# 16                      BUG: Can't create column with  ...       NaT
# 17           ⬆️ UPGRADE: Autoupdate pre-commit config  ...       NaT
# 18         BUG: plot option sort_columns doesn't work  ...       NaT
# 19         TYP: fix a few errors found by pandas-stub  ...       NaT
# 20  DEPR: numeic_only in Series and SeriesGroupBy ...  ...       NaT
# 21        TST: Test aggregate with list values #25581  ...       NaT
# 22                  TYP: misc return type annotations  ...       NaT
# 23  ENH: RangeIndex._shallow_copy can return Range...  ...       NaT
# 24  BUG: Series with same index values, but in dif...  ...       NaT
# 25  ENH/TST: Add BaseMethodsTests tests for ArrowE...  ...       NaT
# 26                          REGR: Ignore eval inplace  ...       NaT
# 27  BUG: incorrect result of applying iloc with slice  ...       NaT
# 28  REGR: NotImplementedErorr: Prefix not defined ...  ...       NaT
# 29  BUG: datetime index name droped after date_ran...  ...       NaT
#
#    author_association active_lock_reason  draft  \
# 0         CONTRIBUTOR                NaN    0.0
# 1              MEMBER                NaN    0.0
# 2              MEMBER                NaN    0.0
# 3                NONE                NaN    NaN
# 4              MEMBER                NaN    0.0
# 5              MEMBER                NaN    NaN
# 6              MEMBER                NaN    0.0
# 7                NONE                NaN    NaN
# 8              MEMBER                NaN    0.0
# 9              MEMBER                NaN    NaN
# 10             MEMBER                NaN    NaN
# 11               NONE                NaN    NaN
# 12               NONE                NaN    0.0
# 13               NONE                NaN    NaN
# 14        CONTRIBUTOR                NaN    0.0
# 15             MEMBER                NaN    NaN
# 16        CONTRIBUTOR                NaN    NaN
# 17        CONTRIBUTOR                NaN    0.0
# 18               NONE                NaN    NaN
# 19        CONTRIBUTOR                NaN    0.0
# 20             MEMBER                NaN    0.0
# 21               NONE                NaN    0.0
# 22        CONTRIBUTOR                NaN    0.0
# 23             MEMBER                NaN    0.0
# 24        CONTRIBUTOR                NaN    NaN
# 25             MEMBER                NaN    0.0
# 26             MEMBER                NaN    0.0
# 27               NONE                NaN    NaN
# 28             MEMBER                NaN    0.0
# 29        CONTRIBUTOR                NaN    NaN
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3                                                 NaN
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5                                                 NaN
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7                                                 NaN
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13                                                NaN
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15                                                NaN
# 16                                                NaN
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18                                                NaN
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24                                                NaN
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27                                                NaN
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
#                                                  body  \
# 0   This PR is quite a bit larger since many funct...
# 1   - [x] closes #47329 (Replace xxxx with the Git...
# 2   - [x] closes #47527 (Replace xxxx with the Git...
# 3   ### Pandas version checks\n\n- [X] I have chec...
# 4   - [ ] closes #xxxx (Replace xxxx with the Gith...
# 5   ### Pandas version checks\n\n- [X] I have chec...
# 6   - [x] closes #47578 (Replace xxxx with the Git...
# 7   ### Pandas version checks\n\n- [X] I have chec...
# 8   - [ ] closes #xxxx (Replace xxxx with the Gith...
# 9   ### Pandas version checks\r\n\r\n- [X] I have ...
# 10  ### Pandas version checks\n\n- [X] I have chec...
# 11  ### Pandas version checks\n\n- [X] I have chec...
# 12  Have added a testcase for quartile performed o...
# 13  #### Is your feature request related to a prob...
# 14  \r\n- [x] closes #46595\r\n- [ ] [Tests added ...
# 15  See https://github.com/pandas-dev/pandas/runs/...
# 16  ### Pandas version checks\n\n- [X] I have chec...
# 17  <!-- START pr-commits -->\n<!-- END pr-commits...
# 18  ### Pandas version checks\r\n\r\n- [X] I have ...
# 19  There are (unsurprisingly) many errors when tr...
# 20  Part of #47500\r\n\r\n- [x] [Tests added and p...
# 21  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 22  After this most of the low hanging return anno...
# 23  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 24  ### Pandas version checks\r\n\r\n- [X] I have ...
# 25  - [ ] [Tests added and passed](https://pandas....
# 26  - [x] closes #47449\r\n- [x] [Tests added and ...
# 27  ### Pandas version checks\r\n\r\n- [X] I have ...
# 28  - [x] closes #46671\r\n- [x] [Tests added and ...
# 29  ### Pandas version checks\n\n- [X] I have chec...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# 5                       NaN          NaN
# 6                       NaN          NaN
# 7                       NaN          NaN
# 8                       NaN          NaN
# 9                       NaN          NaN
# 10                      NaN          NaN
# 11                      NaN          NaN
# 12                      NaN          NaN
# 13                      NaN          NaN
# 14                      NaN          NaN
# 15                      NaN          NaN
# 16                      NaN          NaN
# 17                      NaN          NaN
# 18                      NaN          NaN
# 19                      NaN          NaN
# 20                      NaN          NaN
# 21                      NaN          NaN
# 22                      NaN          NaN
# 23                      NaN          NaN
# 24                      NaN          NaN
# 25                      NaN          NaN
# 26                      NaN          NaN
# 27                      NaN          NaN
# 28                      NaN          NaN
# 29                      NaN          NaN
#
# [30 rows x 30 columns]

# %%
# to load data in raw form
import requests
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47587',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47587/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47587/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47587/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47587',
#   'id': 1292172196,
#   'node_id': 'PR_kwDOAA0YD846v07_',
#   'number': 47587,
#   'title': 'TYP: return values in core/*.py',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-07-03T00:36:12Z',
#   'updated_at': '2022-07-03T02:15:47Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47587',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47587',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47587.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47587.patch',
#    'merged_at': None},
#   'body': 'This PR is quite a bit larger since many functions needed overloads.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47587/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47587/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47586',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47586/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47586/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47586/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47586',
#   'id': 1292162378,
#   'node_id': 'PR_kwDOAA0YD846vzB0',
#   'number': 47586,
#   'title': 'BUG: concat losing columns dtypes for join=outer',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack, Explode'},
#    {'id': 1218227310,
#     'node_id': 'MDU6TGFiZWwxMjE4MjI3MzEw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Index',
#     'name': 'Index',
#     'color': 'e99695',
#     'default': False,
#     'description': 'Related to the Index class or subclasses'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-07-02T23:26:10Z',
#   'updated_at': '2022-07-02T23:32:02Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47586',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47586',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47586.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47586.patch',
#    'merged_at': None},
#   'body': '- [x] closes #47329 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\n@simonjayhawkins This also happens for regular dtypes, so would not backport',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47586/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47586/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47585',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47585/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47585/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47585/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47585',
#   'id': 1292157615,
#   'node_id': 'PR_kwDOAA0YD846vyHh',
#   'number': 47585,
#   'title': 'BUG: Series map ignoring na_action for dict or series mapper',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-07-02T22:48:26Z',
#   'updated_at': '2022-07-02T22:48:26Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47585',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47585',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47585.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47585.patch',
#    'merged_at': None},
#   'body': '- [x] closes #47527 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47585/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47585/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47584',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47584/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47584/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47584/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47584',
#   'id': 1292102669,
#   'node_id': 'I_kwDOAA0YD85NA-wN',
#   'number': 47584,
#   'title': 'DOC: Indicate `formatters` in `DataFrame.to_string` can specify `__index__`',
#   'user': {'login': 'ntjess',
#    'id': 23620506,
#    'node_id': 'MDQ6VXNlcjIzNjIwNTA2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23620506?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ntjess',
#    'html_url': 'https://github.com/ntjess',
#    'followers_url': 'https://api.github.com/users/ntjess/followers',
#    'following_url': 'https://api.github.com/users/ntjess/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ntjess/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/ntjess/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ntjess/subscriptions',
#    'organizations_url': 'https://api.github.com/users/ntjess/orgs',
#    'repos_url': 'https://api.github.com/users/ntjess/repos',
#    'events_url': 'https://api.github.com/users/ntjess/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/ntjess/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-07-02T17:30:55Z',
#   'updated_at': '2022-07-02T17:35:49Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/dev/reference/api/pandas.DataFrame.to_string.html?highlight=formatters\n\n### Documentation problem\n\nThe current  [`to_string`](https://pandas.pydata.org/docs/dev/reference/api/pandas.DataFrame.to_string.html?highlight=formatters) documentation for `formatters` indicates formatting can be applied to columns, but it is unclear whether anything can be set for the index as well. Deep within [`format.py`](https://github.com/pandas-dev/pandas/blob/main/pandas/io/formats/format.py#L962), it appears adding an `__index__` key to formatters will handle this well. I tested with the code below which seemed to work:\r\n\r\n```python\r\nimport pandas as pd\r\nfmt = "{:.4f}".format\r\nfmt_dict = dict(__index__=fmt)\r\nprint(pd.DataFrame([[1,2,3]]).to_string(formatters=fmt_dict))\r\n```\r\n\r\nIs this feature meant to be public? If so, I would recommend exposing it in the `formatters` parameter description. Thanks!\n\n### Suggested fix for documentation\n\nNew `formatters` description resembling the following. Added sentence is italicized:\r\n\r\nFormatter functions to apply to columns’ elements by position or name. The result of each function must be a unicode string. List/tuple must be of length equal to the number of columns. *If a dict-like formatter is specified, the dataframe\'s index can be formatted with an `__index__` key.*\r\n\r\n---\r\n\r\nAlternatively, the MWE in this issue (or something similar) can be added to the `Examples` section.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47584/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47584/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47583',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47583/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47583/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47583/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47583',
#   'id': 1292075128,
#   'node_id': 'PR_kwDOAA0YD846viaA',
#   'number': 47583,
#   'title': 'REF: share DTA/TDA.__init__',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-07-02T15:05:45Z',
#   'updated_at': '2022-07-02T15:05:45Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47583',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47583',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47583.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47583.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47583/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47583/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47582',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47582/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47582/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47582/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47582',
#   'id': 1292041116,
#   'node_id': 'I_kwDOAA0YD85NAvuc',
#   'number': 47582,
#   'title': 'BUG: loc aligning rhs with list indexer but not with scalar',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-07-02T12:04:06Z',
#   'updated_at': '2022-07-02T12:04:13Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nresult = pd.DataFrame({"var": [1, 2]}, index=[1, 2])\r\n\r\nrhs = pd.DataFrame({"a": [10, 11]}, index=[2, 3])\r\n\r\nresult.loc[:, ["var"]] = rhs\r\n\r\nThis aligns the column names and hence returns\r\n\r\n   var\r\n1  NaN\r\n2  NaN\r\n\r\nwhile\r\n\r\nresult = pd.DataFrame({"var": [1, 2]}, index=[1, 2])\r\n\r\nrhs = pd.DataFrame({"a": [10, 11]}, index=[2, 3])\r\n\r\nresult.loc[:, "var"] = rhs\r\n\r\nreturns \r\n\r\n    var\r\n1   NaN\r\n2  10.0\r\n\r\nafter #47578 is fixed. currently this returns\r\n\r\n    var\r\n1   10\r\n2   10\n```\n\n\n### Issue Description\n\nBoth cases should be consistent, I think both of them should align\r\n\r\ncc @jbrockmendel \n\n### Expected Behavior\n\nBoth align\n\n### Installed Versions\n\n<details>\r\n\r\nReplace this line with the output of pd.show_versions()\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47582/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47582/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47581',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47581/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47581/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47581/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47581',
#   'id': 1292039468,
#   'node_id': 'PR_kwDOAA0YD846vbuJ',
#   'number': 47581,
#   'title': 'BUG: DataFrame.loc not aligning rhs df for single block case',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-07-02T11:55:29Z',
#   'updated_at': '2022-07-02T12:00:56Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47581',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47581',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47581.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47581.patch',
#    'merged_at': None},
#   'body': '- [x] closes #47578 (Replace xxxx with the Github issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47581/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47581/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47580',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47580/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47580/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47580/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47580',
#   'id': 1292002886,
#   'node_id': 'I_kwDOAA0YD85NAmZG',
#   'number': 47580,
#   'title': 'BUG: pandas.Series.describe() displays confusing information',
#   'user': {'login': 'Iqigai',
#    'id': 80190909,
#    'node_id': 'MDQ6VXNlcjgwMTkwOTA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80190909?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Iqigai',
#    'html_url': 'https://github.com/Iqigai',
#    'followers_url': 'https://api.github.com/users/Iqigai/followers',
#    'following_url': 'https://api.github.com/users/Iqigai/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Iqigai/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Iqigai/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Iqigai/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Iqigai/orgs',
#    'repos_url': 'https://api.github.com/users/Iqigai/repos',
#    'events_url': 'https://api.github.com/users/Iqigai/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Iqigai/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 34444536,
#     'node_id': 'MDU6TGFiZWwzNDQ0NDUzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Usage%20Question',
#     'name': 'Usage Question',
#     'color': '0052cc',
#     'default': False,
#     'description': None},
#    {'id': 1357732944,
#     'node_id': 'MDU6TGFiZWwxMzU3NzMyOTQ0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Series',
#     'name': 'Series',
#     'color': '8dd5fc',
#     'default': False,
#     'description': 'Series data structure'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-07-02T08:30:11Z',
#   'updated_at': '2022-07-02T19:52:42Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\ns = pd.Series([1, 2 ,3 ,4])\r\ns.describe()\r\n>>>count    4.000000\r\nmean     2.500000\r\nstd      1.290994\r\nmin      1.000000\r\n25%      1.750000\r\n50%      2.500000\r\n75%      3.250000\r\nmax      4.000000\r\ndtype: float64\n```\n\n\n### Issue Description\n\nThe results displayed are a bit incoherent in their format and can create confusion.\r\nFirst, the count is displayed as a float, although it is clearly an int. Same goes for the max and min values\r\nSecond, the dtype information which is displayed seems to correspond to the series returned by the describe() method but that creates confusion as what is expected is information on the Series itself, not meta data.\r\nThe display format are minor issues, but the dtype one can really create confusion as it can be thought of being the dtype of the Series calling the method.\n\n### Expected Behavior\n\nint values should be displayed as int\r\ndtype should refer to the calling Series not the resulting one, or not being displayed at all.\n\n### Installed Versions\n\n<details>\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : e8093ba372f9adfe79439d90fe74b0b5b6dea9d6\r\npython           : 3.10.5.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19043\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 158 Stepping 10, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_Canada.1252\r\npandas           : 1.4.3\r\nnumpy            : 1.22.4\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 62.4.0\r\npip              : 22.1.2\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : 8.4.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmarkupsafe       : None\r\nmatplotlib       : 3.5.2\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.8.1\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47580/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47580/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47579',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47579/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47579/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47579/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47579',
#   'id': 1291947280,
#   'node_id': 'PR_kwDOAA0YD846vKXA',
#   'number': 47579,
#   'title': 'ENH: DTI/DTA.astype support non-nano',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 3713792788,
#     'node_id': 'LA_kwDOAA0YD87dW_sU',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Non-Nano',
#     'name': 'Non-Nano',
#     'color': '006b75',
#     'default': False,
#     'description': 'datetime64/timedelta64 with non-nanosecond resolution'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-07-02T02:56:02Z',
#   'updated_at': '2022-07-02T15:13:54Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47579',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47579',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47579.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47579.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the Github issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47579/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47579/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47578',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47578/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47578/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47578/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47578',
#   'id': 1291892216,
#   'node_id': 'I_kwDOAA0YD85NALX4',
#   'number': 47578,
#   'title': 'BUG: Setting a DataFrame as rhs with loc on a single column does not align in the single block case',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-07-01T22:55:26Z',
#   'updated_at': '2022-07-01T22:56:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nresult = pd.DataFrame({"var": [1, 2]}, index=[1, 2])\r\nrhs = pd.DataFrame({"var": [10, 11]}, index=[2, 3])\r\nresult.loc[:, "var"] = rhs\r\n\r\nreturns\r\n\r\n   var\r\n1   10\r\n2   11\r\n\r\nThis does not align, because it runs through the single_block_path, while non-matching dtypes do align\r\n\r\nresult = pd.DataFrame({"var": [1, 2]}, index=[1, 2])\r\nrhs = pd.DataFrame({"var": ["a", "b"]}, index=[2, 3])\r\nresult.loc[:, "var"] = rhs\r\n\r\n   var\r\n1  NaN\r\n2    a\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\n\r\n\r\nShould be consistent\r\n\r\n### Expected Behavior\r\n\r\nBoth should align. First one should return\r\n\r\n```\r\n   var\r\n1   NaN\r\n2   10.0\r\n```\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\ncommit : https://github.com/pandas-dev/pandas/commit/55d9dcf47dd982248c18237b6a09854ea83bc474\r\npython : 3.8.13.final.0\r\npython-bits : 64\r\nOS : Linux\r\nOS-release : 5.15.0-40-generic\r\nVersion : https://github.com/pandas-dev/pandas/issues/43-Ubuntu SMP Wed Jun 15 12:54:21 UTC 2022\r\nmachine : x86_64\r\nprocessor : x86_64\r\nbyteorder : little\r\nLC_ALL : None\r\nLANG : en_US.UTF-8\r\nLOCALE : en_US.UTF-8\r\n\r\npandas : 1.5.0.dev0+1066.g55d9dcf47d\r\nnumpy : 1.22.4\r\npytz : 2022.1\r\ndateutil : 2.8.2\r\nsetuptools : 62.3.2\r\npip : 22.1.2\r\nCython : 0.29.30\r\npytest : 7.1.2\r\nhypothesis : 6.47.0\r\nsphinx : 4.5.0\r\nblosc : None\r\nfeather : None\r\nxlsxwriter : 3.0.3\r\nlxml.etree : 4.9.0\r\nhtml5lib : 1.1\r\npymysql : None\r\npsycopg2 : None\r\njinja2 : 3.1.2\r\nIPython : 8.4.0\r\npandas_datareader: None\r\nbs4 : 4.11.1\r\nbottleneck : 1.3.4\r\nbrotli :\r\nfastparquet : 0.8.1\r\nfsspec : 2021.11.0\r\ngcsfs : 2021.11.0\r\nmatplotlib : 3.5.2\r\nnumba : 0.53.1\r\nnumexpr : 2.8.0\r\nodfpy : None\r\nopenpyxl : 3.0.9\r\npandas_gbq : None\r\npyarrow : 8.0.0\r\npyreadstat : 1.1.7\r\npyxlsb : None\r\ns3fs : 2021.11.0\r\nscipy : 1.8.1\r\nsnappy :\r\nsqlalchemy : 1.4.37\r\ntables : 3.7.0\r\ntabulate : 0.8.9\r\nxarray : 0.18.2\r\nxlrd : 2.0.1\r\nxlwt : 1.3.0\r\nzstandard : None\r\nNone\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47578/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47578/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47577',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47577/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47577/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47577/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47577',
#   'id': 1291881775,
#   'node_id': 'I_kwDOAA0YD85NAI0v',
#   'number': 47577,
#   'title': 'BUG: Setting incompatible values into ea column raises instead of casting to object',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 1817503692,
#     'node_id': 'MDU6TGFiZWwxODE3NTAzNjky',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/NA%20-%20MaskedArrays',
#     'name': 'NA - MaskedArrays',
#     'color': '8cc645',
#     'default': False,
#     'description': 'Related to pd.NA and nullable extension arrays'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-07-01T22:26:06Z',
#   'updated_at': '2022-07-01T22:26:38Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
# ...
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-06-29T14:53:13Z',
#   'updated_at': '2022-06-29T20:10:20Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the main branch of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\nmidx = pd.MultiIndex.from_product([[\'France\',\'Germany\'], [\'S\',\'W\',\'T\'], [\'A\',\'B\',\'C\']])\r\ncolumns = [\'vol\']\r\ndfmi = pd.DataFrame(np.arange(18).reshape((len(midx), len(columns))),\r\n                    index=midx, columns=columns)\r\ndfmi.sort_index(inplace=True)\r\ndfmi.loc[("France", slice(None), slice("B")),:]\r\n\r\n\r\nRmq: the following is working\r\nidx = pd.IndexSlice\r\ndfmi.loc[idx["France", :, "B"], :]\r\n\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nOutput does not respect the slice on last index            \r\n```\r\n                   vol\r\nFrance S A    0\r\n               B    1\r\n            T A    6\r\n               B    7\r\n           W A    3\r\n              B    4\r\n```\r\n\r\n### Expected Behavior\r\n\r\n       \r\n```\r\n                   vol\r\nFrance S B    1\r\n            T B    7\r\n           W B    4\r\n```\r\n\r\n\r\n\r\n### Installed Versions\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 4bfe3d07b4858144c219b9346329027024102ab6\r\npython           : 3.10.4.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.19042\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 167 Stepping 1, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United Kingdom.1252\r\npandas           : 1.4.2\r\nnumpy            : 1.21.5\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\npip              : 21.2.4\r\nsetuptools       : 61.2.0\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.3\r\nIPython          : 8.3.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : 1.3.4\r\nbrotli           : \r\nfastparquet      : None\r\nfsspec           : 2022.3.0\r\ngcsfs            : None\r\nmarkupsafe       : 2.1.1\r\nmatplotlib       : 3.5.1\r\nnumba            : 0.55.1\r\nnumexpr          : 2.8.1\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 8.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.7.3\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : 0.20.1\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47549/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47549/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47547',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47547/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47547/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47547/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47547',
#   'id': 1288404337,
#   'node_id': 'PR_kwDOAA0YD846jPIc',
#   'number': 47547,
#   'title': 'REGR: NotImplementedErorr: Prefix not defined when slicing offset with loc',
#   'user': {'login': 'CloseChoice',
#    'id': 31857876,
#    'node_id': 'MDQ6VXNlcjMxODU3ODc2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31857876?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CloseChoice',
#    'html_url': 'https://github.com/CloseChoice',
#    'followers_url': 'https://api.github.com/users/CloseChoice/followers',
#    'following_url': 'https://api.github.com/users/CloseChoice/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/CloseChoice/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/CloseChoice/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/CloseChoice/subscriptions',
#    'organizations_url': 'https://api.github.com/users/CloseChoice/orgs',
#    'repos_url': 'https://api.github.com/users/CloseChoice/repos',
#    'events_url': 'https://api.github.com/users/CloseChoice/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/CloseChoice/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/96',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/96',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/96/labels',
#    'id': 8104401,
#    'node_id': 'MI_kwDOAA0YD84Ae6nR',
#    'number': 96,
#    'title': '1.4.4',
#    'description': 'on-merge: backport to 1.4.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 34,
#    'closed_issues': 12,
#    'state': 'open',
#    'created_at': '2022-06-21T19:44:05Z',
#    'updated_at': '2022-07-02T17:04:03Z',
#    'due_on': '2022-07-31T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2022-06-29T09:09:29Z',
#   'updated_at': '2022-07-02T15:26:33Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/47547',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/47547',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/47547.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/47547.patch',
#    'merged_at': None},
#   'body': '- [x] closes #46671\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v1.4.4.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47547/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47547/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47545',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47545/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47545/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47545/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/47545',
#   'id': 1288365319,
#   'node_id': 'I_kwDOAA0YD85MyuUH',
#   'number': 47545,
#   'title': 'BUG: datetime index name droped after date_range selection',
#   'user': {'login': 'SylvainLan',
#    'id': 23078199,
#    'node_id': 'MDQ6VXNlcjIzMDc4MTk5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23078199?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SylvainLan',
#    'html_url': 'https://github.com/SylvainLan',
#    'followers_url': 'https://api.github.com/users/SylvainLan/followers',
#    'following_url': 'https://api.github.com/users/SylvainLan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/SylvainLan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/SylvainLan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/SylvainLan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/SylvainLan/orgs',
#    'repos_url': 'https://api.github.com/users/SylvainLan/repos',
#    'events_url': 'https://api.github.com/users/SylvainLan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/SylvainLan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-06-29T08:36:18Z',
#   'updated_at': '2022-06-29T08:36:18Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the main branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\ndf = pd.DataFrame({'date': [pd.to_datetime(d) for d in ['20220101', '20220102', '20220103']], 'value': [1, 2, 3]})\r\ndf = df.set_index('date')\r\n\r\nprint(df.loc[slice('20220101', '20220102'), :].index.name)\r\nprint(df.loc[pd.date_range('20220101', '20220102'), :].index.name)\n```\n\n\n### Issue Description\n\nHello,\r\n\r\nI realized that using a `date_range` object with `.loc` on a datetime indexed dataframe drops the name of the corresponding index.\r\n\r\nI'm not sure this behavior is normal.\n\n### Expected Behavior\n\nThe name of the index should be kept\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : e8093ba372f9adfe79439d90fe74b0b5b6dea9d6\r\npython           : 3.8.10.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 4.20.0-042000-generic\r\nVersion          : #201812232030 SMP Mon Dec 24 01:32:58 UTC 2018\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.4.3\r\nnumpy            : 1.23.0\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 44.0.0\r\npip              : 20.0.2\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmarkupsafe       : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\n\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47545/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47545/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data1)
# Out:
# 30

# %%
data1[0]['user']
# Out:
# {'login': 'twoertwein',
#  'id': 6618166,
#  'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/twoertwein',
#  'html_url': 'https://github.com/twoertwein',
#  'followers_url': 'https://api.github.com/users/twoertwein/followers',
#  'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#  'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#  'repos_url': 'https://api.github.com/users/twoertwein/repos',
#  'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
data1[0]['user']['id']
# Out:
# 6618166

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 6618166
# 61934744
# 61934744
# 23620506
# 8078968
# 61934744
# 61934744
# 80190909
# 8078968
# 61934744
# 61934744
# 1767010
# 15380498
# 1158542
# 3236794
# 61934744
# 68053396
# 41898282
# 159714
# 6618166
# 45562402
# 97266896
# 6618166
# 10647082
# 15113894
# 10647082
# 31857876
# 1136496
# 31857876
# 23078199

# %%
df2=pd.DataFrame(data1,columns=['id','url','repository_url','labels_url','user'])

# %%
df2.to_csv('json.csv')

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DA98-B1B5
#
#  Directory of C:\Users\user\Desktop\python\Ineoron\pandas
#
# 07/03/2022  02:03 PM    <DIR>          .
# 07/03/2022  02:03 PM    <DIR>          ..
# 07/03/2022  11:27 AM    <DIR>          .ipynb_checkpoints
# 07/03/2022  02:03 PM            34,423 json.csv
# 07/03/2022  10:42 AM            84,319 LUSID Excel - Manage Orders.xlsx
# 07/03/2022  11:39 AM            78,961 nba.csv
# 07/03/2022  11:02 AM            44,115 pandas c1.ipynb
# 07/03/2022  02:03 PM           323,037 pandas c2.ipynb
# 07/03/2022  11:27 AM           576,978 pandas day 2.ipynb
# 07/02/2022  12:37 PM            17,249 Untitled.ipynb
# 07/03/2022  11:10 AM                 0 untitled.txt
#                8 File(s)      1,159,082 bytes
#                3 Dir(s)  46,731,567,104 bytes free
