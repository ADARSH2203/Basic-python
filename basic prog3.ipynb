# %% [raw]
# 1.	Write a Python Program to Check if a Number is Positive, Negative or Zero?
# 2.	Write a Python Program to Check if a Number is Odd or Even?
# 3.	Write a Python Program to Check Leap Year?
# 4.	Write a Python Program to Check Prime Number?
# 5.	Write a Python Program to Print all Prime Numbers in an Interval of 1-10000?

# %%
# Ques1
a= int(input('the number is : '))
import numpy as np
b=np.inf
if a== b:
    print('a is +ve')
elif a== 0:
    print('its 0')
else :
    print('its -ve')
# Out:
# the number is : 5
# its -ve

# %%
a=int(input('this is no : '))

for i in range(0,a,1):
    if i == a:
        print('+ve')
        else:
            print('-ve')
# Out:
#   File "<ipython-input-13-176ea193e51b>", line 6
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
a=5
list(range(0,a,-1))
# Out:
# []

# %%
a=5
for i in range(0,a,-1):
    print('i')

# %%
# solution1
a=int(input('my no is: '))
if a>=1:
    print('+ve')
elif a<=-1:
    print('-ve')
else:
    print('0')
# Out:
# my no is: 0
# 0

# %%
#sol 2
a=int(input('this is my no '))
b=a%2

if b==0 :
    print('its even')
else:
    print('odd')
# Out:
# this is my no 2
# its even

# %%
type(6.5)
# Out:
# float

# %%
# Write a Python Program to Check Leap Year?
a=input('this is year ')
b= int(a[2:3])
if b%4==0:
    print('its leap yr')
else:
    print('not leap yr')
# Out:
# this is year 2026
# not leap yr

# %%
a='2022'
b= int(a[2:4])

# %%
b
# Out:
# 22

# %%
#4 Write a Python Program to Check Prime Number
a=int(input('my no is '))
if a%a == 0:
    print('prime no')
else:
    print('composite')
# Out:
# my no is 6
# prime no

# %% [markdown]
# # ans

# %%
a=int(input('this is my no '))
for i in range(2,a):
    if a%i == 0:
        print('composite no',i)
        break
    else:
        print(a,'is prime')
        break
# Out:
# this is my no 101
# 101 is prime

# %%
a=10
for i in range(1,a):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
n=int(input('my no is '))
i=2

while n%i == 0:
    print ('prime')
    i+=1
    continue
else:
    print('c')
# Out:
# my no is 12
# prime
# prime
# prime
# c

# %%
n=int(input('my no is '))
i=2

while:
    if n%i == 0:
    print ('prime')
    i+=1
    continue
else:
    print('c')
# Out:
#   File "<ipython-input-36-8466de8ad2e3>", line 4
#     while:
#          ^
# SyntaxError: invalid syntax

# %%
a=13
for i in range(2,a+1):
    if (a-1)%i==0:
        print('p',i)
    else :
        print('c',i)
# Out:
# p 2
# p 3
# p 4
# c 5
# p 6
# c 7
# c 8
# c 9
# c 10
# c 11
# p 12
# c 13

# %%
a=12
b=range(2,a)
count=1
for i in b:
    if a%i == 0:
        print(i,' is factorial of ',a)
        continue
# Out:
# 2  is factorial of  12
# 3  is factorial of  12
# 4  is factorial of  12
# 6  is factorial of  12

# %%
a=14
b=range(2,a)
count=1
for i in b:
    if a%i == 0:
        print(i,' is factorial of ',a)
    elif a%i != 1:
        print(a,'is a prime no')
# Out:
# 2  is factorial of  14
# 14 is a prime no
# 14 is a prime no
# 14 is a prime no
# 14 is a prime no
# 7  is factorial of  14
# 14 is a prime no
# 14 is a prime no
# 14 is a prime no
# 14 is a prime no
# 14 is a prime no

# %%
a=1000
b=range(2,a+1)
count=1
for i in b:
    if a%i == 1:
        print(i,' is is prime no between 1 and ',a)
# Out:
# 3  is is prime no between 1 and  1000
# 9  is is prime no between 1 and  1000
# 27  is is prime no between 1 and  1000
# 37  is is prime no between 1 and  1000
# 111  is is prime no between 1 and  1000
# 333  is is prime no between 1 and  1000
# 999  is is prime no between 1 and  1000

# %%
a=int(input('this is my no '))
for i in range(1,a):
    if a%i == 0:
        continue
        print('prime no is',i)
    else:
        print('c',i)
# Out:
# this is my no 100
# c 3
# c 6
# c 7
# c 8
# c 9
# c 11
# c 12
# c 13
# c 14
# c 15
# c 16
# c 17
# c 18
# c 19
# c 21
# c 22
# c 23
# c 24
# c 26
# c 27
# c 28
# c 29
# c 30
# c 31
# c 32
# c 33
# c 34
# c 35
# c 36
# c 37
# c 38
# c 39
# c 40
# c 41
# c 42
# c 43
# c 44
# c 45
# c 46
# c 47
# c 48
# c 49
# c 51
# c 52
# c 53
# c 54
# c 55
# c 56
# c 57
# c 58
# c 59
# c 60
# c 61
# c 62
# c 63
# c 64
# c 65
# c 66
# c 67
# c 68
# c 69
# c 70
# c 71
# c 72
# c 73
# c 74
# c 75
# c 76
# c 77
# c 78
# c 79
# c 80
# c 81
# c 82
# c 83
# c 84
# c 85
# c 86
# c 87
# c 88
# c 89
# c 90
# c 91
# c 92
# c 93
# c 94
# c 95
# c 96
# c 97
# c 98
# c 99

# %%
a=int(input('this is my no '))
#c=range(1,b)
for i in range(1,a+1) :
    if i%range(1,b) == 0:
        continue
    else:
        print(i,'is prime')
# Out:
# this is my no 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f92054b8fd2d> in <module>
#       2 #c=range(1,b)
#       3 for i in range(1,a+1) :
# ----> 4     if i%range(1,b) == 0:
#       5         continue
#       6     else:
#
# NameError: name 'b' is not defined

# %%
5*5
# Out:
# 25

# %%
a=int(input('this is my no '))
#c=range(1,b)
for i in range(1,a+1) :
    for b in range(1,i):
        if i%b == 0:
            continue
        else:
            print('c',i)
# Out:
# this is my no 5
# c 3
# c 4
# c 5
# c 5
# c 5

# %%
a=10
for i in range(1,a+1) :
    for b in range(1,i):
        if i%1 == 0 and i%i==0 and i%b != 0:
            print(i)
# Out:
# 3
# 4
# 5
# 5
# 5
# 6
# 6
# 7
# 7
# 7
# 7
# 7
# 8
# 8
# 8
# 8
# 9
# 9
# 9
# 9
# 9
# 9
# 10
# 10
# 10
# 10
# 10
# 10

# %%
a=10
for i in range(1,a+1) :
    for b in range(1,i+1):
        print(i,b,i%b)
# Out:
# 1 1 0
# 2 1 0
# 2 2 0
# 3 1 0
# 3 2 1
# 3 3 0
# 4 1 0
# 4 2 0
# 4 3 1
# 4 4 0
# 5 1 0
# 5 2 1
# 5 3 2
# 5 4 1
# 5 5 0
# 6 1 0
# 6 2 0
# 6 3 0
# 6 4 2
# 6 5 1
# 6 6 0
# 7 1 0
# 7 2 1
# 7 3 1
# 7 4 3
# 7 5 2
# 7 6 1
# 7 7 0
# 8 1 0
# 8 2 0
# 8 3 2
# 8 4 0
# 8 5 3
# 8 6 2
# 8 7 1
# 8 8 0
# 9 1 0
# 9 2 1
# 9 3 0
# 9 4 1
# 9 5 4
# 9 6 3
# 9 7 2
# 9 8 1
# 9 9 0
# 10 1 0
# 10 2 0
# 10 3 1
# 10 4 2
# 10 5 0
# 10 6 4
# 10 7 3
# 10 8 2
# 10 9 1
# 10 10 0

# %%
a=10
for i in range(1,a+1) :
    for b in range(1,i+1):
        if i%b ==0:
            break
    else:
        print(i)

# %%
lower=0
upper=10

for i in range(lower,upper+1):
    if i>1:
        for j in range(2,i):
            if i%j==0:
                break
            
        else:
            print(i)
# Out:
# 2
# 3
# 5
# 7

# %%
#a=5
b=range(1,a)
#while b<=a:
    print(a*b-1)
#else:
# Out:
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# ...
